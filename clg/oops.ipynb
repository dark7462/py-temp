# %%
class staff:
    uni = "Aditya college of Engg"
    def __init__(self, name, sal):
        self.name = name
        self.sal = sal
    def info(self):
        print("Name : ", self.name)
        print("College : ",self.uni)
        print("Salary : ", self.sal)
class Teacher(staff):
    def __init__(self, name, dept, sal):
        self.name = name
        self.dept = dept
        self.sal = sal
    def info(self):
        print("Name : ", self.name)
        print("College : ",self.uni)
        print("Department : ", self.dept)
        print("Salary : ", self.sal)
class hod(Teacher):
    def __init__(self, name, dept, sal,head):
        self.name = name
        self.dept = dept
        self.sal = sal
        self.head = head
    def info(self):
        print("Name : ", self.name)
        print("College : ",self.uni)
        print("Department : ", self.dept)
        print("Salary : ", self.sal)
        print("Head of : ",self.head,"Department")

def space():
    print("=========================================")
#======================================================================
staff1 = staff("exampla",30000)
staff1.info()
space()
rao_sir = Teacher("Tirumala rao","Ai/Ml",150000)
rao_sir.info()
space()

staff.uni = "Aditya University"
rao_sir.sal = rao_sir.sal + 50000

murthy_sir = Teacher("B.S.N Murthy","Maths",120000)
murthy_sir.info()
space()
rao_sir.info()
space()
chinnaram = hod("Chinna ram girijala","Physics",140000,"Fresh Man Engg")
chinnaram.info()

# %%
class car:
    def __init__(self,make,model,year):
        self.make = make
        self.model = model
        self.year = year
        self.is_started = False
    def start(self):
        if(self.is_started):
            print(f"The {self.year} {self.make} {self.model} is already started.")
            self.is_started = True
        else:
            print(f"The {self.year} {self.make} {self.model} is starting.")
            self.is_started = True
    def stop(self):
        if(self.is_started):
            print(f"The {self.year} {self.make} {self.model} is stopping.")
            self.is_started = False
        else:
            print(f"The {self.year} {self.make} {self.model} is already stopped.")
    def info(self):
        print(f"Car Make: {self.make}")
        print(f"Car Model: {self.model}")
        print(f"Car Year: {self.year}")
        print(f"Is Started: {'Yes' if self.is_started else 'No'}")
car1 = car("Toyota", "Corolla", 2020)
car1.info()
car1.start()
car1.start()
car1.info()
car1.stop()
car1.stop()

# %%
class Animal:
    def make_sound(self):
        raise NotImplementedError("Subclass must implement abstract method 'make_sound'")

class Dog(Animal):
    def make_sound(self):
        return "Woof! Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

class Bird(Animal):
    def make_sound(self):
        return "Chirp! Chirp!"

# Demonstrating polymorphism
print("\n--- Polymorphism Demonstration ---")
animals = [Dog(), Cat(), Bird()]

for animal in animals:
    print(f"An animal makes sound: {animal.make_sound()}")

# %%
#try and except
def safe_divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
        return None
    except TypeError:
        print("Error: Invalid input type. Please provide numbers.")
        return None
    else:
        return result
def main():
    print(safe_divide(10, 2))  # Should print 5.0
    print(safe_divide(10, 0))  # Should print error message
    print(safe_divide(10, 'a'))  # Should print error message
    print(safe_divide(10, 5))  # Should print 2.0 
if __name__ == "__main__":
    main()
